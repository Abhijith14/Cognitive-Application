# %% [markdown]
# # COGNITIVE APPLICATION

# %% [markdown]
# ### Day 1 - Assignment

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>1. Differentiate between Rule-Based Approach and Machine Learning Approach ?</b>

# %% [markdown]
# A <b>Rule-based system</b> uses specific rules to find the ouput from the input data.
# These rules are coded into the system in the form of *if-then-else* statements.
# Rule-based systems aren’t very useful for solving problems in complex domains or across multiple different but simple domains.
# In some situations (tomato and orange, image detection), it’s not even possible to explicitly define rules in a programmatic or declarative way.
# So, the short of it is that rule-based approaches tend to have very poor generalization, but can have excellent performance within a narrow domain.

# %% [markdown]
# <b>Machine learning</b> approaches have a larger variety of performance.
# With machine learning, the computer programs can figure out for themselves how to best achieve those goals and can self-sufficiently improve as they intake more data and experience the results of differing scenarios. This is not possible in Rule-based.
# Machine learning algorithms often have much lower accuracy than rules-based systems until they learn from enough data.
# Machine learning systems aren't trivial to implement, but with the range of powerful tools existing today, from scikit-learn in python, to weka in java, all the way to indico, machine learning approaches can achieve excellent results with very little overhead.

# %% [markdown]
# In short, If you have a dataset (at least 10k examples) then something like sklearn or weka is an excellent bet for good performance without a large overhead, if you don't have those, then using a rule-based system would probably be your best bet.

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>2. Explain the Lifecycle of an ML model ?</b>

# %% [markdown]
# Working of a Machine Learning model can be explained using a life cycle.
#
# It involves 7 major steps:
# - Gathering Data
# - Data Preparation
# - Data Wrangling
# - Analyse Data
# - Train the model
# - Test the model
# - Deployment

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>3. Differentiate between Supervised and Unsupervised learning? Mention real-time
# applications of each ?</b>

# %% [markdown]
# <b>Supervised learning</b> is a machine learning method in which models are trained using labeled data.
# In supervised learning, models need to find the mapping function to map the input variable (X) with the output variable (Y).
#
# Supervised learning can be used for two types of problems: *Classification and Regression*.

# %% [markdown]
# <b><i>EXAMPLE :</i></b>
# Suppose we have an image of different types of fruits. The task of our supervised learning model is to identify the fruits and classify them accordingly. So to identify the image in supervised learning, we will give the input data as well as output for that, which means we will train the model by the shape, size, color, and taste of each fruit. Once the training is completed, we will test the model by giving the new set of fruit. The model will identify the fruit and predict the output using a suitable algorithm.

# %% [markdown]
# <b>Unsupervised learning</b> is another machine learning method in which patterns inferred from the unlabeled input data.
# The goal of unsupervised learning is to find the structure and patterns from the input data.
# Unsupervised learning does not need any supervision.
# Instead, it finds patterns from the data by its own.
#
#
# Unsupervised learning can be used for two types of problems: *Clustering and Association.*

# %% [markdown]
# <b><i>EXAMPLE :</i></b>
# Using the same case of different types of fruits.
# Unlike supervised learning, here we will not provide any supervision to the model. We will just provide the input dataset to the model and allow the model to find the patterns from the data. With the help of a suitable algorithm, the model will train itself and divide the fruits into different groups according to the most similar features between them.

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# <b>4. What do you mean by Clustering ?</b>

# %% [markdown]
# <B>Clustering</B> is the task of dividing the population or data points into a number of groups such that data points in the same groups are more similar to other data points in the same group and dissimilar to the data points in other groups. It is basically a collection of objects on the basis of similarity and dissimilarity between them.
# It is a type of Unsupervised Learning method.

# %% [markdown]
# <br><br>

# %% [markdown]
# <b>5. What is Regression ? Explain with an example ?</b>

# %% [markdown]
# A regression problem is when the output variable is a real or continuous value, such as “salary” or “weight”.
# Many different models can be used, the simplest is the linear regression.
# It tries to fit data with the best hyper-plane which goes through the points.

# %% [markdown]
# Types of Regression –
#
# - Linear regression
# - Logistic regression
# - Polynomial regression
# - Stepwise regression
# - Stepwise regression
# - Ridge regression
# - Lasso regression
# - ElasticNet regression

# %% [markdown]
# <b><i>EXAMPLE :</i></b>
# - Predicting age of a person
# - Predicting house price based on area

# %% [markdown]
# <br><br>

# %% [markdown]
# <b>6. How do we check the efficiency of an ML model ? Mention the parameters. </b>

# %% [markdown]
# Models Performance can be measured using :
#
# 1.Confusion matrix <br>
# 2.Accuracy <br>
# 3.Precision <br>
# 4.Recall <br>
# 5.Specificity <br>
# 6.F1 score <br>
# 7.Precision-Recall or PR curve <br>
# 8.ROC (Receiver Operating Characteristics) curve

# %% [markdown]
# Considering an example of a binary classification problem (cats or dogs/ have cancer(positive) or is found healthy) We have,
#
# True positives (TP): Predicted positive and are actually positive. <br>
# False positives (FP): Predicted positive and are actually negative. <br>
# True negatives (TN): Predicted negative and are actually negative. <br>
# False negatives (FN): Predicted negative and are actually positive.

# %% [markdown]
# <b><u>1. Confusion Matrix</u></b>

# %% [markdown]
# It’s just a representation of the above parameters in a matrix format.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>2. Accuracy</u></b>

# %% [markdown]
# The most commonly used metric to judge a model and is actually not a clear indicator of the performance. The worse happens when classes are imbalanced.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Take for example a cancer detection model. The chances of actually having cancer are very low. Let’s say out of 100, 90 of the patients don’t have cancer and the remaining 10 actually have it. We don’t want to miss on a patient who is having cancer but goes undetected (false negative). Detecting everyone as not having cancer gives an accuracy of 90% straight. The model did nothing here but just gave cancer free for all the 100 predictions.

# %% [markdown]
# <b><u>3. Precision</u></b>

# %% [markdown]
# Percentage of positive instances out of the total predicted positive instances. Here denominator is the model prediction done as positive from the whole given dataset. In short, it is *how much the model is right when it says it is right*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>4. Recall/Sensitivity/True Positive Rate</u></b>

# %% [markdown]
# Percentage of positive instances out of the total actual positive instances. Therefore denominator (TP + FN) here is the actual number of positive instances present in the dataset. In short, it is *how much extra right ones, the model missed when it showed the right ones*

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>5. Specificity</u></b>

# %% [markdown]
# Percentage of negative instances out of the total actual negative instances. Therefore denominator (TN + FP) here is the actual number of negative instances present in the dataset. It is similar to recall but the shift is on the negative instances. Like finding out how many healthy patients were not having cancer and were told they don’t have cancer. Kind of a measure to see how separate the classes are.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>6. F1 Score</u></b>

# %% [markdown]
# It is the harmonic mean of precision and recall. This takes the contribution of both, so higher the F1 score, the better. See that due to the product in the numerator if one goes low, the final F1 score goes down significantly. So a model does well in F1 score if the positive predicted are actually positives (precision) and doesn't miss out on positives and predicts them negative (recall).

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>7. PR Curve</u></b>

# %% [markdown]
# *It is the curve between precision and recall for various threshold values.* In the figure below we have 6 predictors showing their respective precision-recall curve for various threshold values. The top right part of the graph is the ideal space where we get high precision and recall. Based on our application we can choose the predictor and the threshold value. PR AUC is just the area under the curve. The higher its numerical value the better.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b><u>8. ROC curve</u></b>

# %% [markdown]
# ROC stands for receiver operating characteristic and the graph is plotted against TPR and FPR for various threshold values. As TPR increases FPR also increases. As you can see in the first figure, we have four categories and we want the threshold value that leads us closer to the top left corner. Comparing different predictors (here 3) on a given dataset also becomes easy as you can see in figure 2, one can choose the threshold according to the application at hand. ROC AUC is just the area under the curve, the higher its numerical value the better.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
